# %%
# !pip install -q gpt_2_simple
# Out:
#      |████████████████████████████████| 655kB 9.4MB/s
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Building wheel for regex (setup.py) ... done

# %%
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0709 15:38:50.213837 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
gpt2.download_gpt2(model_name="345M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 261Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 82.9Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 243Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:12, 110Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 217Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 82.2Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 104Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpt2.copy_file_from_gdrive("cover_letters_gpt2.csv")

# %%
file_name = "cover_letters_gpt2.csv"

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              learning_rate=1e-4,
              dataset=file_name,
              model_name='345M',
              steps=1000,
              restore_from='fresh',
              print_every=10,
              sample_every=50,
              save_every=100
)
# Out:
# W0709 15:56:53.684387 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:90: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0709 15:56:53.689270 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:100: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0709 15:56:53.841610 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:164: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0709 15:56:53.851350 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0709 15:57:07.164197 140121824597888 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:71: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0709 15:57:07.186014 140121824597888 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0709 15:57:07.190033 140121824597888 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:77: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# W0709 15:57:07.207458 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:191: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0709 15:57:25.163223 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:198: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0709 15:57:25.166419 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:200: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0709 15:57:25.168633 140121824597888 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py:202: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0709 15:57:45.611798 140121824597888 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading checkpoint models/345M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00, 19.60it/s]
# Loading dataset...
# dataset has 518186 tokens
# Training...
# [10 | 971.01] loss=2.24 avg=2.24
# [20 | 1927.41] loss=1.82 avg=2.03
# [30 | 2886.36] loss=1.94 avg=2.00
# [40 | 3846.13] loss=1.92 avg=1.98
# [50 | 4801.52] loss=2.12 avg=2.01
# ======== SAMPLE 1 ========
#  me, and it's not every day that I'm able to reach out and say hello. It was always very easy to learn the ropes while working, since I had always had a steady income and the ability to maintain expenses and my personal standards. With that said, as a career coach, I'm well aware of the challenges and frustrations that managers have when recruiting and retaining a coach. A great deal of communication is required between employees, and I feel comfortable working close to the customer-driven teams at your institution. There is just one thing I would like you to know about me and my background: I'm a great motivator for the job!My experience includes teaching English as well as introducing a wide range of lessons with my students. The following examples demonstrate my current and previous teaching talents, and my commitment to creating the learning experiences I expect to create each day at your institution.Here are some examples of my current teaching responsibilities:At your next opportunity to interview for the role of English Teacher at your institution, I will make a formal offer for the position. I look forward to hearing from you soon.Thank you for your consideration.Sincerely,
# Samantha Bowers<|endoftext|>
# <|startoftext|>Dear Mr. Nardone,I would like to learn more about your department here at Bikes & Skills.When I first read the job ad for a Bikes & Skills instructor, I immediately thought it would be a perfect fit for my current needs. With my education at the hands of a high school teacher, my strong technical skills that I learned with my father at the same time I learned a variety of technical concepts and has provided me with much to offer the Bikes & Skills team at Bikes & Skills.From building a bike, teaching students how to ride, and getting them to follow the instructor, I would be a great fit for your department. I am aware of the value and importance of building skills that will enable professionals and individuals to make a difference in the lives of others.My expertise in mechanics of bikes and motorcycles, including maintenance and repairing, will certainly make a positive impact on your job. Thank you for your consideration.Sincerely,
# Elizabeth McCarter<|endoftext|>
# <|startoftext|>Dear Mr. M. Gaski,I am submitting my resume for the position of a Bachelor in Pharmacy at SUNY Buffalo. With my bachelor degree in Pharmacology, my experience and strengths as an experienced pharmacologist will allow me to make a significant impact on your nursing department’s success.My Bachelor’s degree in Pharmacology brings me to the pharmacy profession where I understand the importance it has in your department. With my clinical leadership experience and comprehensive knowledge, I will add great value to your department in this position.My professional development and experience at a pharmacy in a major international organization has prepared me to achieve the goals and objectives of your department as your pharmacist. I am passionate about promoting the highest standards of pharmacy care.To learn more about my qualifications, please contact me at your earliest convenience in future communications.Thank thee for your time and consideration, and I look forward to hearing from you.Sincerely,
# Garry N. W. Hall<|endoftext|>
# <|startoftext|>Dear Mr. Jones,I was interested in the opportunity to interview for the Pharmacist role you have available for a Bachelors in Pharmacy. The following highlights and testimonials from my past educational and professional experience has been posted on your website:My professional experience has brought me great comfort and pleasure to administer medicines to the patient. To that end, I am committed to creating a rewarding and professional experience for you.I will be meeting with you this week to discuss my skills and qualifications. If you would be interested in having me as an Advisor to your student, I would be happy to put on my presentation.Thank you for your consideration.Sincerely,
# Herman W. Williams<|endoftext|>
# <|startoftext|>Dear Mr. Givens:When I learned of your posting for a Pharmacist, I quickly decided to apply for the position. In this role you provide all of the tools and resources you need to achieve success and make a positive impact on your clients.My experience in healthcare and practice management has allowed me to develop a unique set of learning capabilities that will allow me to thrive in this position. I am determined that my patients will look at the best of the professionals I offer, and my dedication to developing the best education and support plans will make a positive impact in the Pharmacist.Here are some highlights of my professional experience:My commitment to providing outstanding healthcare and practice management has allowed me to help a wide range of patients throughout their treatment histories and increase customer satisfaction. I consider my education, training, and experience within Medicine and Pharmacy a tremendous asset to your organization. As an energetic and accomplished Practitioner, I am prepared to dedicate myself
#
# [60 | 6056.20] loss=1.86 avg=1.98
# [70 | 7020.98] loss=1.81 avg=1.96
# [80 | 7985.09] loss=1.36 avg=1.88
# [90 | 8948.70] loss=1.68 avg=1.86
# [100 | 9911.27] loss=2.68 avg=1.94
# Saving checkpoint/run1/model-100
# ======== SAMPLE 1 ========
# . This week, we'll see when the day will be my last! My professional experience is filled with many things that are essential. One of which is being able to analyze a problem for solutions. Here are my skills as a professional analyst: Analyzing computer-generated data. Analyzing databases. Developing new systems and software products. Analyzing software packages. Creating reports and charts and managing budgets. These skills, combined, give me a keen aptitude for analysis. I have also developed a deep knowledge of accounting terms. These skills, combined with my hardworking ability, drive me to excel in both managerial and production roles.
# My resume will be attached to this post. The following are some highlights of my qualifications, which I have highlighted for you.
# You will find myself greatly motivated to apply for your first interview at which you will assess my skills and experience and make suggestions for my future professional opportunities. I look forward to meeting with you and speaking with you further about my qualifications. I look forward to receiving your resume.
# Thank you for considering my application and thank you for your time.
# Sincerely,
# Nigel L. Clark<|endoftext|>
# <|startoftext|>Dear Mr. Wills:Upon review of your website, I was immediately motivated to submit my resume for consideration for your review. As a seasoned administrator with extensive experience overseeing a full range of IT, data and IT infrastructure work with various clients, I am confident in my ability to substantially benefit your organization.From managing IT systems, developing user interfaces and creating documents, to developing and executing business functions, my career accomplishments have proven highly successful. I have been involved in implementing enterprise-level IT systems, software upgrades and monitoring systems. I have also been involved in running performance assessments where I have successfully identified improvements and have acted as a point of reference for management teams within IT. In fact, my skills—as well as my ability to thrive in challenging environments to optimize IT performance—will undoubtedly make me an immediate asset to your company.Highlights of my experience include…My skills in technical IT systems and IT work have been finely honed. My skills in IT and IT related business development are also well-proven, and I have been able to apply my skills and experience to both front- and back-office IT systems and business solutions. Furthermore, my ability to effectively communicate with clients and collaborate with peers to achieve results—combined with my strong work ethic—makes me a formidable asset to your company.The following are additional highlights of my education and experience from my past: My experience in IT software engineering and management have been highly rated by supervisors and students. These highlights will demonstrate the depth of my qualifications; however, I am available for future career interviews and I would gladly speak with you further about my qualifications.Thank you for your time and consideration.Sincerely,
# Dennis E. Hines<|endoftext|>
# <|startoftext|>Dear Mr. Sowell:Upon review of your posting for a new IT support specialist, I hastened to submit my resume for your consideration. As an accomplished and highly qualified professional with expertise in software and hardware support and maintenance projects, including hardware repair, computer software and hardware upgrades, I feel confident that my skills, technical, time-effective expertise, and communication and organizational skills will make me an immediate asset to your organization.My work experience includes troubleshooting software updates and issues that have arisen in the IT department and leading to the complete or partial disassembly of systems. My background includes troubleshooting software upgrades and maintaining Windows operating systems up to and including Linux versions.My background includes developing system and software packages that allow the overall IT level to be maintained with minimum of maintenance. My ability and willingness to work together with peers, directors, managers, and supervisors to achieve results and achieve goals has made me an asset to your organization.I am fluent in several Microsoft languages and have extensive experience working in IT. I have received excellent reviews from department managers from both IT department and the corporate world. My knowledge of Windows has also been proven to be an asset to various departments as well as has a solid foundation in information technology.Please be aware that my specific skills, experience, training, and qualifications will only be relevant to your IT department. To apply for my role, please go to the job page.The following are my qualifications, as provided by my resume:My proven ability to handle IT support and software upgrades, combined with my outstanding time management capacity, will make me an immediate asset to your organization. I look forward to discussing the position in the upcoming interview.If you are interested in becoming part of your IT team, then I would love to be interviewed. I am available for interview through the email address you provided.I look forward to hearing from you and hearing more specifics.
# Sincerely,William C. Ritter<|endoftext|>
# <|startoftext|>Dear Mr. Sowell,Upon review of your posting for a new IT Support Specialist
#
# [110 | 11192.94] loss=1.60 avg=1.91
# [120 | 12172.54] loss=1.63 avg=1.89
# [130 | 13151.37] loss=1.53 avg=1.86
# [140 | 14131.48] loss=1.40 avg=1.82
# interrupted
# Saving checkpoint/run1/model-144
# W0709 20:01:45.096581 140121824597888 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run1')
